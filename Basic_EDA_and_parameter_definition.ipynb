# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import seaborn as sn

# %%
#infosys stock data
data=pd.read_csv("C:\\Users\\anjit\\Desktop\\New folder\\CL\\INFY.csv")

# %%
data.head()
# Out:
#   Symbol Series         Date  Prev Close  Open Price  High Price  Low Price  \
# 0   INFY     EQ  15-May-2017      964.25       963.5      963.50     949.10
# 1   INFY     EQ  16-May-2017      951.55       953.1      960.15     946.95
# 2   INFY     EQ  17-May-2017      955.00       951.6      958.45     943.85
# 3   INFY     EQ  18-May-2017      952.80       943.0      973.90     942.85
# 4   INFY     EQ  19-May-2017      961.75       961.5      962.70     947.85
#
#    Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0      953.25       951.55         951.49                3648582
# 1      956.00       955.00         952.92                3065084
# 2      952.90       952.80         949.48                1457754
# 3      960.25       961.75         962.61                4028924
# 4      957.40       957.95         954.18                2128698
#
#        Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# 0  3.471580e+09          75335          3052819                   83.67
# 1  2.920775e+09          71808          1858063                   60.62
# 2  1.384110e+09          75429           792251                   54.35
# 3  3.878282e+09         120990          2309450                   57.32
# 4  2.031155e+09          88897          1457747                   68.48

# %%
data.tail()
# Out:
#     Symbol Series         Date  Prev Close  Open Price  High Price  Low Price  \
# 491   INFY     EQ  07-May-2019      718.40      720.40      727.90      718.7
# 492   INFY     EQ  08-May-2019      724.55      721.00      726.00      716.5
# 493   INFY     EQ  09-May-2019      719.35      719.15      730.30      715.8
# 494   INFY     EQ  10-May-2019      721.05      720.80      726.00      715.0
# 495   INFY     EQ  13-May-2019      716.85      716.55      726.45      712.1
#
#      Last Price  Close Price  Average Price  Total Traded Quantity  \
# 491      724.40       724.55         724.51                5747536
# 492      718.95       719.35         721.65                6247642
# 493      722.00       721.05         724.48                7396525
# 494      716.50       716.85         717.88                8352335
# 495      718.00       719.70         720.09                6808993
#
#          Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# 491  4.164127e+09         104342          3690425                   64.21
# 492  4.508603e+09         162077          3950857                   63.24
# 493  5.358635e+09         242225          4808832                   65.01
# 494  5.995942e+09         181229          5545377                   66.39
# 495  4.903098e+09         201194          4745909                   69.70

# %%
data.describe()
# Out:
#         Prev Close   Open Price   High Price    Low Price   Last Price  \
# count   496.000000   496.000000   496.000000   496.000000   496.000000
# mean    961.505746   960.166331   970.148589   950.189415   959.942843
# std     220.856495   220.105831   223.013281   218.694264   220.978683
# min     619.100000   621.000000   628.000000   599.850000   619.500000
# 25%     734.950000   736.050000   742.475000   729.037500   734.375000
# 50%     956.750000   955.825000   963.925000   947.675000   955.675000
# 75%    1150.212500  1145.137500  1161.425000  1135.887500  1147.850000
# max    1441.100000  1449.000000  1467.900000  1430.000000  1440.000000
#
#        Close Price  Average Price  Total Traded Quantity      Turnover  \
# count    496.00000     496.000000           4.960000e+02  4.960000e+02
# mean     960.04254     960.262399           6.037975e+06  5.452230e+09
# std      221.03952     221.113239           5.448129e+06  4.768762e+09
# min      619.10000     613.780000           5.457170e+05  5.060941e+08
# 25%      734.78750     735.672500           3.133640e+06  3.343381e+09
# 50%      955.25000     954.550000           4.880990e+06  4.592718e+09
# 75%     1150.05000    1148.220000           7.290372e+06  6.015533e+09
# max     1441.10000    1451.300000           8.220248e+07  7.662502e+10
#
#        No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# count   4.960000e+02     4.960000e+02              496.000000
# mean    1.355993e+05     3.594822e+06               61.711593
# std     8.583843e+04     2.840850e+06               10.428229
# min     1.000000e+00     0.000000e+00                0.000000
# 25%     9.208100e+04     2.059041e+06               55.110000
# 50%     1.195405e+05     3.051691e+06               62.270000
# 75%     1.551135e+05     4.324140e+06               68.792500
# max     1.192900e+06     4.202849e+07              100.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 496 entries, 0 to 495
# Data columns (total 15 columns):
# Symbol                    496 non-null object
# Series                    496 non-null object
# Date                      496 non-null object
# Prev Close                496 non-null float64
# Open Price                496 non-null float64
# High Price                496 non-null float64
# Low Price                 496 non-null float64
# Last Price                496 non-null float64
# Close Price               496 non-null float64
# Average Price             496 non-null float64
# Total Traded Quantity     496 non-null int64
# Turnover                  496 non-null float64
# No. of Trades             496 non-null int64
# Deliverable Qty           496 non-null int64
# % Dly Qt to Traded Qty    496 non-null float64
# dtypes: float64(9), int64(3), object(3)
# memory usage: 58.2+ KB

# %%
data['Date']= pd.to_datetime(data['Date'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 496 entries, 0 to 495
# Data columns (total 15 columns):
# Symbol                    496 non-null object
# Series                    496 non-null object
# Date                      496 non-null datetime64[ns]
# Prev Close                496 non-null float64
# Open Price                496 non-null float64
# High Price                496 non-null float64
# Low Price                 496 non-null float64
# Last Price                496 non-null float64
# Close Price               496 non-null float64
# Average Price             496 non-null float64
# Total Traded Quantity     496 non-null int64
# Turnover                  496 non-null float64
# No. of Trades             496 non-null int64
# Deliverable Qty           496 non-null int64
# % Dly Qt to Traded Qty    496 non-null float64
# dtypes: datetime64[ns](1), float64(9), int64(3), object(2)
# memory usage: 58.2+ KB

# %%
data['Date'].max()
# Out:
# Timestamp('2019-05-13 00:00:00')

# %%
data['Date'].min()
# Out:
# Timestamp('2017-05-15 00:00:00')

# %%
data['Date'].max()-data['Date'].min()
# Out:
# Timedelta('728 days 00:00:00')

# %%
lst_ninty=data.tail(n=90)

# %%
lst_ninty['Close Price'].mean(),lst_ninty['Close Price'].max(),lst_ninty['Close Price'].min()
# Out:
# (730.2683333333333, 767.25, 661.05)

# %%
import datetime

# %%
data['Year'] = pd.DatetimeIndex(data['Date']).year
data['Month'] = pd.DatetimeIndex(data['Date']).month

# %%
data.head()
# Out:
#   Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 0   INFY     EQ 2017-05-15      964.25       963.5      963.50     949.10
# 1   INFY     EQ 2017-05-16      951.55       953.1      960.15     946.95
# 2   INFY     EQ 2017-05-17      955.00       951.6      958.45     943.85
# 3   INFY     EQ 2017-05-18      952.80       943.0      973.90     942.85
# 4   INFY     EQ 2017-05-19      961.75       961.5      962.70     947.85
#
#    Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0      953.25       951.55         951.49                3648582
# 1      956.00       955.00         952.92                3065084
# 2      952.90       952.80         949.48                1457754
# 3      960.25       961.75         962.61                4028924
# 4      957.40       957.95         954.18                2128698
#
#        Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty  Year  \
# 0  3.471580e+09          75335          3052819                   83.67  2017
# 1  2.920775e+09          71808          1858063                   60.62  2017
# 2  1.384110e+09          75429           792251                   54.35  2017
# 3  3.878282e+09         120990          2309450                   57.32  2017
# 4  2.031155e+09          88897          1457747                   68.48  2017
#
#    Month
# 0      5
# 1      5
# 2      5
# 3      5
# 4      5

# %%
data['Series'].unique()
# Out:
# array(['EQ'], dtype=object)

# %%
data.groupby('Series').describe()
# Out:
#        Prev Close                                                           \
#             count        mean         std    min      25%     50%      75%
# Series
# EQ          494.0  961.440789  220.761549  619.1  735.025  956.75  1150.15
#
#                Open Price             ...    Year          Month           \
#            max      count       mean  ...     75%     max  count     mean
# Series                                ...
# EQ      1441.1      494.0  961.07004  ...  2018.0  2019.0  494.0  6.48583
#
#
#              std  min  25%  50%  75%   max
# Series
# EQ      3.455131  1.0  4.0  6.5  9.0  12.0
#
# [1 rows x 112 columns]

# %%
data.drop( data[ data['Series'] == 'BL' ].index , inplace=True)

# %%
data['Series'].unique()
# Out:
# array(['EQ'], dtype=object)

# %%
data.head()
# Out:
#   Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 0   INFY     EQ 2017-05-15      964.25       963.5      963.50     949.10
# 1   INFY     EQ 2017-05-16      951.55       953.1      960.15     946.95
# 2   INFY     EQ 2017-05-17      955.00       951.6      958.45     943.85
# 3   INFY     EQ 2017-05-18      952.80       943.0      973.90     942.85
# 4   INFY     EQ 2017-05-19      961.75       961.5      962.70     947.85
#
#    Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0      953.25       951.55         951.49                3648582
# 1      956.00       955.00         952.92                3065084
# 2      952.90       952.80         949.48                1457754
# 3      960.25       961.75         962.61                4028924
# 4      957.40       957.95         954.18                2128698
#
#        Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty  Year  \
# 0  3.471580e+09          75335          3052819                   83.67  2017
# 1  2.920775e+09          71808          1858063                   60.62  2017
# 2  1.384110e+09          75429           792251                   54.35  2017
# 3  3.878282e+09         120990          2309450                   57.32  2017
# 4  2.031155e+09          88897          1457747                   68.48  2017
#
#    Month
# 0      5
# 1      5
# 2      5
# 3      5
# 4      5

# %%
gk=data.groupby(['Month','Year'])

# %%
data1=data.copy()

# %%
grps=list(gk.groups)

# %%
grps
# Out:
# [(1, 2018),
#  (1, 2019),
#  (2, 2018),
#  (2, 2019),
#  (3, 2018),
#  (3, 2019),
#  (4, 2018),
#  (4, 2019),
#  (5, 2017),
#  (5, 2018),
#  (5, 2019),
#  (6, 2017),
#  (6, 2018),
#  (7, 2017),
#  (7, 2018),
#  (8, 2017),
#  (8, 2018),
#  (9, 2017),
#  (9, 2018),
#  (10, 2017),
#  (10, 2018),
#  (11, 2017),
#  (11, 2018),
#  (12, 2017),
#  (12, 2018)]

# %%
#function to calculate monthwise Volume weighted average
def vvap(data):
    v=sum(data['Close Price']*data['Total Traded Quantity'])/sum(data['Total Traded Quantity'])
    return(v)

# %%
vwap=gk.apply(vvap)

# %%
vwap
# Out:
# Month  Year
# 1      2018    1114.434642
#        2019     708.054850
# 2      2018    1137.523710
#        2019     746.052269
# 3      2018    1162.184207
#        2019     724.365636
# 4      2018    1153.567462
#        2019     739.025955
# 5      2017     969.171663
#        2018    1197.926656
#        2019     721.403986
# 6      2017     948.202546
#        2018    1263.282758
# 7      2017     979.204067
#        2018    1329.247518
# 8      2017     919.396317
#        2018    1396.527179
# 9      2017     897.396520
#        2018     752.570451
# 10     2017     931.858118
#        2018     688.817051
# 11     2017     969.989288
#        2018     650.652805
# 12     2017    1011.833961
#        2018     670.195881
# dtype: float64

# %%
vwap.max()
# Out:
# 1396.5271791573416

# %%
#average price over last N days
def avg_price_n_days(days):
    avg=sum(data['Close Price'].tail(n=days))/days
    return avg

# %%
avg_price_n_days(7),avg_price_n_days(14),avg_price_n_days(30),avg_price_n_days(90),avg_price_n_days(180),avg_price_n_days(365)
# Out:
# (720.5,
#  726.9928571428572,
#  736.7966666666666,
#  728.6027777777778,
#  758.6911111111111,
#  966.8810958904111)

# %%
vwap.plot()
plt.show()

# %%
#funtion to find profit or loss percentage change over last N days
def perc_change_n_days(days):
    perc_change=data['Close Price'].tail(n=days).pct_change()*100
    l=perc_change.to_list()
    del l[0]
    avrg=sum(l)/days
    return avrg

# %%
perc_change_n_days(7),perc_change_n_days(14),perc_change_n_days(30),perc_change_n_days(90),perc_change_n_days(180),perc_change_n_days(365)
# Out:
# (-0.07554765410990713,
#  -0.006518983890928024,
#  -0.03911410870960549,
#  0.1057635973919559,
#  -0.2615600700699556,
#  -0.022605272792195964)

# %%
data.head()
# Out:
#   Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 0   INFY     EQ 2017-05-15      964.25       963.5      963.50     949.10
# 1   INFY     EQ 2017-05-16      951.55       953.1      960.15     946.95
# 2   INFY     EQ 2017-05-17      955.00       951.6      958.45     943.85
# 3   INFY     EQ 2017-05-18      952.80       943.0      973.90     942.85
# 4   INFY     EQ 2017-05-19      961.75       961.5      962.70     947.85
#
#    Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0      953.25       951.55         951.49                3648582
# 1      956.00       955.00         952.92                3065084
# 2      952.90       952.80         949.48                1457754
# 3      960.25       961.75         962.61                4028924
# 4      957.40       957.95         954.18                2128698
#
#        Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty  Year  \
# 0  3.471580e+09          75335          3052819                   83.67  2017
# 1  2.920775e+09          71808          1858063                   60.62  2017
# 2  1.384110e+09          75429           792251                   54.35  2017
# 3  3.878282e+09         120990          2309450                   57.32  2017
# 4  2.031155e+09          88897          1457747                   68.48  2017
#
#    Month
# 0      5
# 1      5
# 2      5
# 3      5
# 4      5

# %%
data['Day_Perc_change']=data['Close Price'].pct_change()*100 #add new colmn Day_Per_Change which id percentage change between two concecutive days close prices

# %%
data.head()
# Out:
#   Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 0   INFY     EQ 2017-05-15      964.25       963.5      963.50     949.10
# 1   INFY     EQ 2017-05-16      951.55       953.1      960.15     946.95
# 2   INFY     EQ 2017-05-17      955.00       951.6      958.45     943.85
# 3   INFY     EQ 2017-05-18      952.80       943.0      973.90     942.85
# 4   INFY     EQ 2017-05-19      961.75       961.5      962.70     947.85
#
#    Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0      953.25       951.55         951.49                3648582
# 1      956.00       955.00         952.92                3065084
# 2      952.90       952.80         949.48                1457754
# 3      960.25       961.75         962.61                4028924
# 4      957.40       957.95         954.18                2128698
#
#        Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty  Year  \
# 0  3.471580e+09          75335          3052819                   83.67  2017
# 1  2.920775e+09          71808          1858063                   60.62  2017
# 2  1.384110e+09          75429           792251                   54.35  2017
# 3  3.878282e+09         120990          2309450                   57.32  2017
# 4  2.031155e+09          88897          1457747                   68.48  2017
#
#    Month  Day_Perc_change
# 0      5              NaN
# 1      5         0.362566
# 2      5        -0.230366
# 3      5         0.939337
# 4      5        -0.395113

# %%
data['Day_Perc_change'] = data['Day_Perc_change'].fillna(0)#removing Nan value

# %%
data.head()
# Out:
#   Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 0   INFY     EQ 2017-05-15      964.25       963.5      963.50     949.10
# 1   INFY     EQ 2017-05-16      951.55       953.1      960.15     946.95
# 2   INFY     EQ 2017-05-17      955.00       951.6      958.45     943.85
# 3   INFY     EQ 2017-05-18      952.80       943.0      973.90     942.85
# 4   INFY     EQ 2017-05-19      961.75       961.5      962.70     947.85
#
#    Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0      953.25       951.55         951.49                3648582
# 1      956.00       955.00         952.92                3065084
# 2      952.90       952.80         949.48                1457754
# 3      960.25       961.75         962.61                4028924
# 4      957.40       957.95         954.18                2128698
#
#        Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty  Year  \
# 0  3.471580e+09          75335          3052819                   83.67  2017
# 1  2.920775e+09          71808          1858063                   60.62  2017
# 2  1.384110e+09          75429           792251                   54.35  2017
# 3  3.878282e+09         120990          2309450                   57.32  2017
# 4  2.031155e+09          88897          1457747                   68.48  2017
#
#    Month  Day_Perc_change
# 0      5         0.000000
# 1      5         0.362566
# 2      5        -0.230366
# 3      5         0.939337
# 4      5        -0.395113

# %%
#Defining trend based on daily percentage change
def trend(data):
    if -0.5<data['Day_Perc_change']<0.5:
        return 'slight'
    elif 0.5<data['Day_Perc_change']<1:
        return 'slight positive'
    elif -1<data['Day_Perc_change']<-0.5:
        return 'slight negative'
    elif 1<data['Day_Perc_change']<3:
        return 'positive'
    elif -3<data['Day_Perc_change']<-1:
        return 'negative'
    elif 3<data['Day_Perc_change']<7:
        return 'Among top gainers'
    elif -7<data['Day_Perc_change']<-3:
        return 'Among top losers'
    elif data['Day_Perc_change']<-7:
        return 'bull drop'
    elif data['Day_Perc_change']>-7:
        return 'bull run'
    else:
        return'nan'

# %%
data['Trend']=data.apply(trend, axis=1) #adding new column Trend based on conditions defied in the above function based on column Day_Perc_change

# %%
data
# Out:
#     Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 0     INFY     EQ 2017-05-15      964.25      963.50      963.50     949.10
# 1     INFY     EQ 2017-05-16      951.55      953.10      960.15     946.95
# 2     INFY     EQ 2017-05-17      955.00      951.60      958.45     943.85
# 3     INFY     EQ 2017-05-18      952.80      943.00      973.90     942.85
# 4     INFY     EQ 2017-05-19      961.75      961.50      962.70     947.85
# ..     ...    ...        ...         ...         ...         ...        ...
# 491   INFY     EQ 2019-05-07      718.40      720.40      727.90     718.70
# 492   INFY     EQ 2019-05-08      724.55      721.00      726.00     716.50
# 493   INFY     EQ 2019-05-09      719.35      719.15      730.30     715.80
# 494   INFY     EQ 2019-05-10      721.05      720.80      726.00     715.00
# 495   INFY     EQ 2019-05-13      716.85      716.55      726.45     712.10
#
#      Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0        953.25       951.55         951.49                3648582
# 1        956.00       955.00         952.92                3065084
# 2        952.90       952.80         949.48                1457754
# 3        960.25       961.75         962.61                4028924
# 4        957.40       957.95         954.18                2128698
# ..          ...          ...            ...                    ...
# 491      724.40       724.55         724.51                5747536
# 492      718.95       719.35         721.65                6247642
# 493      722.00       721.05         724.48                7396525
# 494      716.50       716.85         717.88                8352335
# 495      718.00       719.70         720.09                6808993
#
#          Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty  \
# 0    3.471580e+09          75335          3052819                   83.67
# 1    2.920775e+09          71808          1858063                   60.62
# 2    1.384110e+09          75429           792251                   54.35
# 3    3.878282e+09         120990          2309450                   57.32
# 4    2.031155e+09          88897          1457747                   68.48
# ..            ...            ...              ...                     ...
# 491  4.164127e+09         104342          3690425                   64.21
# 492  4.508603e+09         162077          3950857                   63.24
# 493  5.358635e+09         242225          4808832                   65.01
# 494  5.995942e+09         181229          5545377                   66.39
# 495  4.903098e+09         201194          4745909                   69.70
#
#      Year  Month  Day_Perc_change            Trend
# 0    2017      5         0.000000           slight
# 1    2017      5         0.362566           slight
# 2    2017      5        -0.230366           slight
# 3    2017      5         0.939337  slight positive
# 4    2017      5        -0.395113           slight
# ..    ...    ...              ...              ...
# 491  2019      5         0.856069  slight positive
# 492  2019      5        -0.717687  slight negative
# 493  2019      5         0.236324           slight
# 494  2019      5        -0.582484  slight negative
# 495  2019      5         0.397573           slight
#
# [494 rows x 19 columns]

# %%
tr=data.groupby(['Trend']) #

# %%
trg=list(tr.groups)

# %%
trg#list of groups formed
# Out:
# ['Among top gainers',
#  'Among top losers',
#  'bull drop',
#  'negative',
#  'positive',
#  'slight',
#  'slight negative',
#  'slight positive']

# %%
type(tr)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
tr.first()#first entries of each group
# Out:
#                   Symbol Series       Date  Prev Close  Open Price  \
# Trend
# Among top gainers   INFY     EQ 2017-08-17      975.20      1005.0
# Among top losers    INFY     EQ 2017-08-21      923.25       924.0
# bull drop           INFY     EQ 2017-08-18     1020.85      1017.9
# negative            INFY     EQ 2017-05-29      995.70       990.9
# positive            INFY     EQ 2017-05-25      954.80       961.0
# slight              INFY     EQ 2017-05-15      964.25       963.5
# slight negative     INFY     EQ 2017-06-01      977.05       969.3
# slight positive     INFY     EQ 2017-05-18      952.80       943.0
#
#                    High Price  Low Price  Last Price  Close Price  \
# Trend
# Among top gainers     1029.25     998.05     1021.05      1020.85
# Among top losers       924.00     870.00      870.15       873.40
# bull drop             1017.90     884.20      923.15       923.25
# negative               996.70     975.70      986.00       985.15
# positive               986.60     961.00      981.00       983.30
# slight                 963.50     949.10      953.25       951.55
# slight negative        979.70     958.55      971.25       971.40
# slight positive        973.90     942.85      960.25       961.75
#
#                    Average Price  Total Traded Quantity      Turnover  \
# Trend
# Among top gainers        1012.61               12892130  1.305476e+10
# Among top losers          888.68               45203588  4.017148e+10
# bull drop                 932.15               82202480  7.662502e+10
# negative                  983.11                3154217  3.100929e+09
# positive                  978.16                5219257  5.105250e+09
# slight                    951.49                3648582  3.471580e+09
# slight negative           969.49                2754303  2.670263e+09
# slight positive           962.61                4028924  3.878282e+09
#
#                    No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty  \
# Trend
# Among top gainers         219380          8130105                   63.06
# Among top losers          844350         20137307                   44.55
# bull drop                1192900         42028494                   51.13
# negative                   83084          2272869                   72.06
# positive                   76160          4108984                   78.73
# slight                     75335          3052819                   83.67
# slight negative            81421          1822506                   66.17
# slight positive           120990          2309450                   57.32
#
#                    Year  Month  Day_Perc_change
# Trend
# Among top gainers  2017      8         4.681091
# Among top losers   2017      8        -5.399404
# bull drop          2017      8        -9.560660
# negative           2017      5        -1.059556
# positive           2017      5         2.984918
# slight             2017      5         0.000000
# slight negative    2017      6        -0.578271
# slight positive    2017      5         0.939337

# %%
tr['Total Traded Quantity'].sum()
# Out:
# Trend
# Among top gainers    151087534
# Among top losers     131746836
# bull drop             97572604
# negative             490171179
# positive             705486215
# slight               725085416
# slight negative      316370979
# slight positive      374323658
# Name: Total Traded Quantity, dtype: int64

# %%
tr['Total Traded Quantity'].median()#median of Total Traded Quantity for each trend groups
# Out:
# Trend
# Among top gainers    12042170.5
# Among top losers     10985897.0
# bull drop            48786302.0
# negative              5088554.0
# positive              5523811.5
# slight                4043539.5
# slight negative       4616803.0
# slight positive       5301784.0
# Name: Total Traded Quantity, dtype: float64

# %%
tr.size()
# Out:
# Trend
# Among top gainers     12
# Among top losers       9
# bull drop              2
# negative              87
# positive             106
# slight               156
# slight negative       58
# slight positive       64
# dtype: int64

# %%
average_trend=tr['Total Traded Quantity'].sum()/tr.size() #avaerage of Total Traded Quantity for each trend groups

# %%
average_trend
# Out:
# Trend
# Among top gainers    1.259063e+07
# Among top losers     1.463854e+07
# bull drop            4.878630e+07
# negative             5.634151e+06
# positive             6.655530e+06
# slight               4.647983e+06
# slight negative      5.454672e+06
# slight positive      5.848807e+06
# dtype: float64

# %%
data.to_csv('C:\\Users\\anjit\\Desktop\\New folder\\CL\\week2.csv')
